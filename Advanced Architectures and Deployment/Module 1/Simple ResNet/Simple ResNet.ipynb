# %% [markdown]
# # Simple ResNet Model

# %% [markdown]
# ## Importing Packages

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchinfo
from torchvision import transforms
from torchvision.datasets import ImageFolder

from torch.utils.data import Dataset, DataLoader, random_split

import helper_utils

# Set seed
SEED = 42

# %% [markdown]
# # SOME HYPERPARAMETERS

# %%
BATCH_SIZE = 32
LEARNING_RATE = 1e-3    
NUM_EPOCHS = 5

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
dataset_path = "data"

# %%
# Display the image count statistics for each class.
helper_utils.display_dataset_stats(dataset_path)
# Out:
# <style type="text/css">
# #T_36431 table {
#   width: 60%;
#   margin: 0;
# }
# #T_36431 td {
#   text-align: left;
#   padding: 8px;
# }
# #T_36431 th {
#   text-align: left;
#   padding: 8px;
#   background-color: #4f4f4f;
#   color: white;
# }
# #T_36431_row0_col0, #T_36431_row0_col1, #T_36431_row1_col0, #T_36431_row1_col1, #T_36431_row2_col0, #T_36431_row2_col1, #T_36431_row3_col0, #T_36431_row3_col1, #T_36431_row4_col0, #T_36431_row4_col1, #T_36431_row5_col0, #T_36431_row5_col1, #T_36431_row6_col0, #T_36431_row6_col1, #T_36431_row7_col0, #T_36431_row7_col1, #T_36431_row8_col0, #T_36431_row8_col1, #T_36431_row9_col0, #T_36431_row9_col1, #T_36431_row10_col0, #T_36431_row10_col1, #T_36431_row11_col0, #T_36431_row11_col1, #T_36431_row12_col0, #T_36431_row12_col1, #T_36431_row13_col0, #T_36431_row13_col1, #T_36431_row14_col0, #T_36431_row14_col1, #T_36431_row15_col0, #T_36431_row15_col1 {
#   white-space: normal;
# }
# </style>
# <table id="T_36431">
#   <thead>
#     <tr>
#       <th id="T_36431_level0_col0" class="col_heading level0 col0" >Class Name</th>
#       <th id="T_36431_level0_col1" class="col_heading level0 col1" >Number of Images</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_36431_row0_col0" class="data row0 col0" >Agriculture</td>
#       <td id="T_36431_row0_col1" class="data row0 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row1_col0" class="data row1 col0" >Airport</td>
#       <td id="T_36431_row1_col1" class="data row1 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row2_col0" class="data row2 col0" >Beach</td>
#       <td id="T_36431_row2_col1" class="data row2 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row3_col0" class="data row3 col0" >City</td>
#       <td id="T_36431_row3_col1" class="data row3 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row4_col0" class="data row4 col0" >Desert</td>
#       <td id="T_36431_row4_col1" class="data row4 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row5_col0" class="data row5 col0" >Forest</td>
#       <td id="T_36431_row5_col1" class="data row5 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row6_col0" class="data row6 col0" >Grassland</td>
#       <td id="T_36431_row6_col1" class="data row6 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row7_col0" class="data row7 col0" >Highway</td>
#       <td id="T_36431_row7_col1" class="data row7 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row8_col0" class="data row8 col0" >Lake</td>
#       <td id="T_36431_row8_col1" class="data row8 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row9_col0" class="data row9 col0" >Mountain</td>
#       <td id="T_36431_row9_col1" class="data row9 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row10_col0" class="data row10 col0" >Parking</td>
#       <td id="T_36431_row10_col1" class="data row10 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row11_col0" class="data row11 col0" >Port</td>
#       <td id="T_36431_row11_col1" class="data row11 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row12_col0" class="data row12 col0" >Railway</td>
#       <td id="T_36431_row12_col1" class="data row12 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row13_col0" class="data row13 col0" >Residential</td>
#       <td id="T_36431_row13_col1" class="data row13 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row14_col0" class="data row14 col0" >River</td>
#       <td id="T_36431_row14_col1" class="data row14 col1" >800</td>
#     </tr>
#     <tr>
#       <td id="T_36431_row15_col0" class="data row15 col0" ><b>Total</b></td>
#       <td id="T_36431_row15_col1" class="data row15 col1" >12000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Pre-calculated mean and std of this dataset
mean = [0.378, 0.393, 0.345]
std = [0.205, 0.173, 0.170]

# Transforms for Training data with augmentations
train_transforms = transforms.Compose([
    transforms.RandomResizedCrop(size = (100, 100), scale = (0.8, 1.0)),
    transforms.RandomHorizontalFlip(p = 0.5),
    transforms.RandomVerticalFlip(p = 0.5),
    transforms.RandomRotation(degrees = 15),
    transforms.ColorJitter(brightness = 0.2, contrast = 0.2, saturation = 0.2, hue = 0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean = mean, std = std)
])

# Transforms for Validation and Test data (no augmentations)
val_transforms = transforms.Compose([
    transforms.Resize((100, 100)),
    transforms.ToTensor(),
    transforms.Normalize(mean = mean, std = std)
])

# %%
skyview_dataset = ImageFolder(root = dataset_path, transform = None)

# Calculate the number of samples for training, validation and testing
total_samples = len(skyview_dataset)

train_size = int (0.7 * total_samples)
val_size = int(0.15 * total_samples)
test_size = total_samples - train_size - val_size

# Split the dataset into training, validation and testing sets
train_data, val_data, test_data = random_split(skyview_dataset, [train_size, val_size, test_size], generator = torch.Generator().manual_seed(SEED))

# %% [markdown]
# # Dataset Class

# %%
class ImgDataset(Dataset):
    def __init__ (self, data, transform = None):
        super().__init__()

        self.data = data
        self.transform = transform

        self.classes = data.dataset.classes

    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        img, label = self.data[index]

        if self.transform:
            img = self.transform(img)

        return img, label

# %%
train_dataset = ImgDataset(data = train_data, transform = train_transforms)
val_dataset = ImgDataset(data = val_data, transform = val_transforms)
test_dataset = ImgDataset(data = test_data, transform = val_transforms)

num_classes = 15

# %% [markdown]
# ## DataLoaders

# %%
train_loader = DataLoader(dataset = train_dataset, batch_size = BATCH_SIZE, shuffle = True)
val_loader = DataLoader(dataset = val_dataset, batch_size = BATCH_SIZE, shuffle = False)
test_loader = DataLoader(dataset = test_dataset, batch_size= 1, shuffle = False)

# %% [markdown]
# # Simple ResNet Components

# %% [markdown]
# ## Residual Block

# %%
# class ResidualBlock(nn.Module):
#     def __init__(self, in_channels, out_channels, stride = 1, downsample = None):
#         # Initialize the parent nn.Module class
#         super(ResidualBlock, self).__init__()

#         # Fist component of the main path
#         self.convblock1 = nn.Sequential(
#             nn.Conv2d(
#                 in_channels = in_channels,
#                 out_channels = out_channels,
#                 kernel_size = 3,
#                 stride = stride,
#                 padding = 1,
#                 bias = False
#             ),
#             nn.BatchNorm2d(out_channels),
#             nn.ReLU(inplace = True)
#         )

#         # Second component of the main path
#         self.convblock2 = nn.Sequential(
#             nn.Conv2d(
#                 in_channels = out_channels,
#                 out_channels = out_channels,
#                 kernel_size = 3,
#                 stride = 1,
#                 padding = 1,
#                 bias = False
#             ),
#             nn.BatchNorm2d(out_channels),

#         )

#         # Optional downsampling layer for the skip connection
#         self.downsample = downsample

#     def _initial_forward(self, x):
#         out = self.convblock1(x)
#         out = self.convblock2(out)

#         return out

#     def forward(self, x):

#         # stores the input for the skip connection
#         identity = x

#         out = self._initial_forward(x)

#         # Apply downsampling to the identity if needed to match out dimensions
#         if self.downsample is not None:
#             identity = self.downsample(x)

#         out += identity

#         # Apply final ReLU activation after adding the skip connection
#         out = F.relu(out)

#         return out

# %% [markdown]
# ## Simple ResNet Class

# %%
# class SimpleResNet(nn.Module):
#     def __init__(self, num_classes = 5, num_blocks = [2, 2, 2]):
#         super(SimpleResNet, self).__init__()

#         # Define the number of classes and blocks for each stage of the ResNet architecture
#         # Define the final number of classes for the output layer
#         self.num_classes = num_classes

#         # Define the number of blocks for each stage of the ResNet architecture (e.g., [2, 2, 2] for ResNet-18)
#         self.num_blocks = num_blocks

#         self.in_channels = 32

#         # Define the initial convolutional block
#         self.initial_block = self._get_initial_block()

#         # Define the residual blocks for the ResNet architecture
#         self.res_block1 = self._make_residual_block(out_channels = 32, num_blocks = self.num_blocks[0], stride = 1)
#         self.res_block2 = self._make_residual_block(out_channels = 64, num_blocks = self.num_blocks[1], stride = 2)
#         self.res_block3 = self._make_residual_block(out_channels = 128, num_blocks = self.num_blocks[2], stride = 2)

#         # Define the final classification block
#         self.final_block = self._get_final_block()
        

        


#     def _make_residual_block(self, out_channels, num_blocks, stride):

#         downsample = None

#         if stride != 1 or self.in_channels != out_channels:
#             downsample = nn.Sequential(
#                 nn.Conv2d(self.in_channels, 
#                           out_channels, 
#                           kernel_size = 1,
#                           stride = stride,
#                           bias = False),
#                 nn.BatchNorm2d(out_channels)
#             )

#         layers = []

#         first_block = ResidualBlock(in_channels = self.in_channels, out_channels = out_channels, stride = stride, downsample = downsample)

#         layers.append(first_block)

#         self.in_channels = out_channels

#         for _ in range(1, num_blocks):
#             layers.append(ResidualBlock(in_channels = out_channels, out_channels = out_channels))

#         return nn.Sequential(*layers)
        
#     def _get_initial_block(self):
#         initial_block = nn.Sequential(
#             nn.Conv2d(3, 32, kernel_size = 3, stride = 1, padding = 1, bias = False),
#             nn.BatchNorm2d(32),
#             nn.ReLU(inplace = True)
#         )
#         return initial_block
        
#     def _get_final_block(self):
#         final_block = nn.Sequential(
#             nn.AdaptiveAvgPool2d((1, 1)),
#             nn.Flatten(),
#             nn.Linear(self.in_channels, self.num_classes)
#         )
#         return final_block
    
#     def forward(self, x):
#         x = self.initial_block(x)

#         x = self.res_block1(x)
#         x = self.res_block2(x)
#         x = self.res_block3(x)

#         x = self.final_block(x)

#         return x

# %% [markdown]
# ## Model Initialization

# %%
# torch.manual_seed(SEED)

# model = SimpleResNet(num_classes = num_classes)

# %% [markdown]
# ## Model Architecture Verification

# %%
# # Define a configuration dictionary to store parameters for the model summary.
# config = {
#     "input_size": (BATCH_SIZE, 3, 64, 64),
#     "attr_names": ["input_size", "output_size", "num_params", "trainable"],
#     "col_names_display": ["Input Shape ", "Output Shape", "Param #", "Trainable"],
#     "depth": 3
# }

# # Generate the model summary object using torchinfo with the specified configuration.
# summary = torchinfo.summary(
#     model=model, 
#     input_size=config["input_size"], 
#     col_names=config["attr_names"], 
#     depth=config["depth"]
# )

# # Display the summary as a styled HTML table.
# print("--- Model Summary ---\n")
# helper_utils.display_torch_summary(summary, config["attr_names"], config["col_names_display"], config["depth"])

# %% [markdown]
# ### Second attempt at defining the model and generating the summary with the correct variable names.

# %%
# Defining Subclasses

class InitialBlock(nn.Sequential):
    pass

class ResNetStage(nn.Sequential):
    pass

class FinalBlock(nn.Sequential):
    pass

class StageContainerDict(nn.ModuleDict):
    pass

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, downsample = None, stride = 1):
        super(ResidualBlock, self).__init__()

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.stride = stride
        self.downsample = downsample



        self.convblock1 = nn.Sequential(
            nn.Conv2d(
                in_channels = self.in_channels,
                out_channels = self.out_channels,
                kernel_size = 3,
                stride = self.stride,
                padding = 1,
                bias = False
            ),
            nn.BatchNorm2d(self.out_channels),
            nn.ReLU(inplace = True)
        )

        self.convblock2 = nn.Sequential(
            nn.Conv2d(
                in_channels = self.out_channels,
                out_channels = self.out_channels,
                kernel_size=3,
                stride = 1,
                padding = 1,
                bias = False
            ),
            nn.BatchNorm2d(self.out_channels)
        )

    def _initial_forward(self, x):

        identity = x

        if self.downsample is not None:
            identity = self.downsample(identity)

        out = self.convblock1(x)
        out = self.convblock2(out)

        return identity, out
    
    def forward(self, x):
        identity, out = self._initial_forward(x)

        out += identity

        out = F.relu(out)

        return out

# %%
class SimpleResNet(nn.Module):
    def __init__(self, num_classes, in_channels = 32, num_blocks = [2, 2, 2], channel_dims = [32, 64, 128]):
        super(SimpleResNet, self).__init__()

        self.num_classes = num_classes
        self.in_channels = in_channels
        self.num_blocks = num_blocks
        self.channel_dims = channel_dims

        self.stages = StageContainerDict()
        
        self.initialblock = self._create_initial_block()

        for i in range(len(self.num_blocks)):
            out_channels = self.channel_dims[i]
            blocks = self.num_blocks[i]

            stride = 1 if i == 0 else 2

            stage = self._create_stage(blocks = blocks, out_channels = out_channels, stride = stride)
            stage_name = f"stage_{i + 1}"
            self.stages[stage_name] = stage

        self.finalblock = self._create_final_block()



    def _create_initial_block(self):
        initial_block = InitialBlock(
            nn.Conv2d(
                in_channels = 3, 
                out_channels = self.in_channels,
                kernel_size = 3,
                stride = 1,
                padding = 1,
                bias = False),

            nn.BatchNorm2d(self.in_channels),
            nn.ReLU(inplace=True)
        )

        return initial_block
    


    def _create_stage(self, blocks, out_channels, stride, downsample = None):

        layers = []
        
        if self.in_channels != out_channels or stride != 1:
            downsample = nn.Sequential(
                nn.Conv2d(self.in_channels, out_channels, kernel_size = 1, stride = stride, bias = False),
                nn.BatchNorm2d(out_channels))
            
        layers.append(ResidualBlock(in_channels = self.in_channels, out_channels = out_channels, downsample = downsample, stride = stride))

        self.in_channels = out_channels
            
        for _ in range(1, blocks):
            block = ResidualBlock(in_channels = out_channels, out_channels = out_channels, downsample = None, stride = 1)

            layers.append(block)

        return ResNetStage(*layers)



    def _create_final_block(self):
        final_block = FinalBlock(
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten(),
            nn.Linear(self.in_channels, self.num_classes)
        )

        return final_block

    
    
    def forward(self, x):
        x = self.initialblock(x)

        for name, stage in self.stages.items():
            x = stage(x)

        x = self.finalblock(x)

        return x

# %% [markdown]
# ## Model Initialization

# %%
torch.manual_seed(SEED)

model1 = SimpleResNet(num_classes = num_classes)
model2 = SimpleResNet(num_blocks = [3, 3, 3], num_classes = num_classes)

# %% [markdown]
# ## Model Architecture Verification

# %%
# Define a configuration dictionary to store parameters for the model summary
config = {
    "input_size": (BATCH_SIZE, 3, 64, 64),
    "attr_names": ["input_size", "output_size", "num_params", "trainable"],
    "col_names_display": ["Input Shape ", "Output Shape", "Param #", "Trainable"],
    "depth": 10
}

# Generate the model summary object using torchinfo with the specified configuration.
summary = torchinfo.summary(
    model=model1, 
    input_size=config["input_size"], 
    col_names=config["attr_names"], 
    depth=config["depth"],
    row_settings=["var_names"]
)

# Display the summary as a styled HTML table.
print("--- Model Summary ---\n")
helper_utils.display_torch_summary(summary, config["attr_names"], config["col_names_display"], config["depth"])
# Out:
# --- Model Summary ---
# <style type="text/css">
# #T_8daff table {
#   width: 100%;
#   border-collapse: collapse;
# }
# #T_8daff th {
#   text-align: left;
#   padding: 8px;
#   background-color: #4f4f4f;
#   color: white;
#   border-bottom: 1px solid #ddd;
# }
# #T_8daff td {
#   text-align: left;
#   padding: 8px;
#   border-bottom: 1px solid #ddd;
# }
# #T_8daff_row0_col0, #T_8daff_row0_col1, #T_8daff_row0_col2, #T_8daff_row0_col3, #T_8daff_row0_col4, #T_8daff_row1_col0, #T_8daff_row1_col1, #T_8daff_row1_col2, #T_8daff_row1_col3, #T_8daff_row1_col4, #T_8daff_row2_col0, #T_8daff_row2_col1, #T_8daff_row2_col2, #T_8daff_row2_col3, #T_8daff_row2_col4, #T_8daff_row3_col0, #T_8daff_row3_col1, #T_8daff_row3_col2, #T_8daff_row3_col3, #T_8daff_row3_col4, #T_8daff_row4_col0, #T_8daff_row4_col1, #T_8daff_row4_col2, #T_8daff_row4_col3, #T_8daff_row4_col4, #T_8daff_row5_col0, #T_8daff_row5_col1, #T_8daff_row5_col2, #T_8daff_row5_col3, #T_8daff_row5_col4, #T_8daff_row6_col0, #T_8daff_row6_col1, #T_8daff_row6_col2, #T_8daff_row6_col3, #T_8daff_row6_col4, #T_8daff_row7_col0, #T_8daff_row7_col1, #T_8daff_row7_col2, #T_8daff_row7_col3, #T_8daff_row7_col4, #T_8daff_row8_col0, #T_8daff_row8_col1, #T_8daff_row8_col2, #T_8daff_row8_col3, #T_8daff_row8_col4, #T_8daff_row9_col0, #T_8daff_row9_col1, #T_8daff_row9_col2, #T_8daff_row9_col3, #T_8daff_row9_col4, #T_8daff_row10_col0, #T_8daff_row10_col1, #T_8daff_row10_col2, #T_8daff_row10_col3, #T_8daff_row10_col4, #T_8daff_row11_col0, #T_8daff_row11_col1, #T_8daff_row11_col2, #T_8daff_row11_col3, #T_8daff_row11_col4, #T_8daff_row12_col0, #T_8daff_row12_col1, #T_8daff_row12_col2, #T_8daff_row12_col3, #T_8daff_row12_col4, #T_8daff_row13_col0, #T_8daff_row13_col1, #T_8daff_row13_col2, #T_8daff_row13_col3, #T_8daff_row13_col4, #T_8daff_row14_col0, #T_8daff_row14_col1, #T_8daff_row14_col2, #T_8daff_row14_col3, #T_8daff_row14_col4, #T_8daff_row15_col0, #T_8daff_row15_col1, #T_8daff_row15_col2, #T_8daff_row15_col3, #T_8daff_row15_col4, #T_8daff_row16_col0, #T_8daff_row16_col1, #T_8daff_row16_col2, #T_8daff_row16_col3, #T_8daff_row16_col4, #T_8daff_row17_col0, #T_8daff_row17_col1, #T_8daff_row17_col2, #T_8daff_row17_col3, #T_8daff_row17_col4, #T_8daff_row18_col0, #T_8daff_row18_col1, #T_8daff_row18_col2, #T_8daff_row18_col3, #T_8daff_row18_col4, #T_8daff_row19_col0, #T_8daff_row19_col1, #T_8daff_row19_col2, #T_8daff_row19_col3, #T_8daff_row19_col4, #T_8daff_row20_col0, #T_8daff_row20_col1, #T_8daff_row20_col2, #T_8daff_row20_col3, #T_8daff_row20_col4, #T_8daff_row21_col0, #T_8daff_row21_col1, #T_8daff_row21_col2, #T_8daff_row21_col3, #T_8daff_row21_col4, #T_8daff_row22_col0, #T_8daff_row22_col1, #T_8daff_row22_col2, #T_8daff_row22_col3, #T_8daff_row22_col4, #T_8daff_row23_col0, #T_8daff_row23_col1, #T_8daff_row23_col2, #T_8daff_row23_col3, #T_8daff_row23_col4, #T_8daff_row24_col0, #T_8daff_row24_col1, #T_8daff_row24_col2, #T_8daff_row24_col3, #T_8daff_row24_col4, #T_8daff_row25_col0, #T_8daff_row25_col1, #T_8daff_row25_col2, #T_8daff_row25_col3, #T_8daff_row25_col4, #T_8daff_row26_col0, #T_8daff_row26_col1, #T_8daff_row26_col2, #T_8daff_row26_col3, #T_8daff_row26_col4, #T_8daff_row27_col0, #T_8daff_row27_col1, #T_8daff_row27_col2, #T_8daff_row27_col3, #T_8daff_row27_col4, #T_8daff_row28_col0, #T_8daff_row28_col1, #T_8daff_row28_col2, #T_8daff_row28_col3, #T_8daff_row28_col4, #T_8daff_row29_col0, #T_8daff_row29_col1, #T_8daff_row29_col2, #T_8daff_row29_col3, #T_8daff_row29_col4, #T_8daff_row30_col0, #T_8daff_row30_col1, #T_8daff_row30_col2, #T_8daff_row30_col3, #T_8daff_row30_col4, #T_8daff_row31_col0, #T_8daff_row31_col1, #T_8daff_row31_col2, #T_8daff_row31_col3, #T_8daff_row31_col4, #T_8daff_row32_col0, #T_8daff_row32_col1, #T_8daff_row32_col2, #T_8daff_row32_col3, #T_8daff_row32_col4, #T_8daff_row33_col0, #T_8daff_row33_col1, #T_8daff_row33_col2, #T_8daff_row33_col3, #T_8daff_row33_col4, #T_8daff_row34_col0, #T_8daff_row34_col1, #T_8daff_row34_col2, #T_8daff_row34_col3, #T_8daff_row34_col4, #T_8daff_row35_col0, #T_8daff_row35_col1, #T_8daff_row35_col2, #T_8daff_row35_col3, #T_8daff_row35_col4, #T_8daff_row36_col0, #T_8daff_row36_col1, #T_8daff_row36_col2, #T_8daff_row36_col3, #T_8daff_row36_col4, #T_8daff_row37_col0, #T_8daff_row37_col1, #T_8daff_row37_col2, #T_8daff_row37_col3, #T_8daff_row37_col4, #T_8daff_row38_col0, #T_8daff_row38_col1, #T_8daff_row38_col ...
#   white-space: pre;
#   vertical-align: top;
# }
# </style>
# <table id="T_8daff">
#   <thead>
#     <tr>
#       <th id="T_8daff_level0_col0" class="col_heading level0 col0" >Layer (type:depth-idx)</th>
#       <th id="T_8daff_level0_col1" class="col_heading level0 col1" >Input Shape </th>
#       <th id="T_8daff_level0_col2" class="col_heading level0 col2" >Output Shape</th>
#       <th id="T_8daff_level0_col3" class="col_heading level0 col3" >Param #</th>
#       <th id="T_8daff_level0_col4" class="col_heading level0 col4" >Trainable</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8daff_row0_col0" class="data row0 col0" >SimpleResNet</td>
#       <td id="T_8daff_row0_col1" class="data row0 col1" >[32, 3, 64, 64

# %% [markdown]
# ## Loss Function and Optimizer

# %%
loss_function = nn.CrossEntropyLoss()

optimizer1 = optim.Adam(model1.parameters(), lr = LEARNING_RATE)
optimizer2 = optim.Adam(model2.parameters(), lr = LEARNING_RATE)

# %% [markdown]
# ## Model Training and Validation

# %%
trained_resnet1, history_resnet1, cm_resnet1 = helper_utils.training_loop_16_mixed(
    model=model1,
    train_loader=train_loader,
    val_loader=val_loader,
    loss_function=loss_function,
    optimizer=optimizer1,
    num_epochs=NUM_EPOCHS,
    device=device
)

trained_resnet2, history_resnet2, cm_resnet2 = helper_utils.training_loop_16_mixed(
    model=model2,
    train_loader=train_loader,
    val_loader=val_loader,
    loss_function=loss_function,
    optimizer=optimizer2,   
    num_epochs=NUM_EPOCHS,
    device=device
)
# Out:
# Epoch 1/5 [Training]:   0%|          | 0/263 [00:00<?, ?it/s]
# Epoch 1/5 [Validation]:   0%|          | 0/57 [00:00<?, ?it/s]
# Epoch 1/5 - Train Loss: 1.7877, Val Loss: 1.7399, Val Acc: 0.4435
# Epoch 2/5 [Training]:   0%|          | 0/263 [00:00<?, ?it/s]
# Epoch 2/5 [Validation]:   0%|          | 0/57 [00:00<?, ?it/s]
# Epoch 2/5 - Train Loss: 1.4069, Val Loss: 1.1205, Val Acc: 0.6196
# Epoch 3/5 [Training]:   0%|          | 0/263 [00:00<?, ?it/s]
# Epoch 3/5 [Validation]:   0%|          | 0/57 [00:00<?, ?it/s]
# Epoch 3/5 - Train Loss: 1.2366, Val Loss: 1.2145, Val Acc: 0.6100
# Epoch 4/5 [Training]:   0%|          | 0/263 [00:00<?, ?it/s]
# Epoch 4/5 [Validation]:   0%|          | 0/57 [00:00<?, ?it/s]
# Epoch 4/5 - Train Loss: 1.1412, Val Loss: 1.0859, Val Acc: 0.6315
# Epoch 5/5 [Training]:   0%|          | 0/263 [00:00<?, ?it/s]
# Epoch 5/5 [Validation]:   0%|          | 0/57 [00:00<?, ?it/s]
# Epoch 5/5 - Train Loss: 1.0534, Val Loss: 0.9648, Val Acc: 0.6695
# Epoch 1/5 [Training]:   0%|          | 0/263 [00:00<?, ?it/s]
# Epoch 1/5 [Validation]:   0%|          | 0/57 [00:00<?, ?it/s]
# Epoch 1/5 - Train Loss: 1.8230, Val Loss: 1.8277, Val Acc: 0.4026
# Epoch 2/5 [Training]:   0%|          | 0/263 [00:00<?, ?it/s]
# Epoch 2/5 [Validation]:   0%|          | 0/57 [00:00<?, ?it/s]
# Epoch 2/5 - Train Loss: 1.4916, Val Loss: 1.4150, Val Acc: 0.5028
# Epoch 3/5 [Training]:   0%|          | 0/263 [00:00<?, ?it/s]
# Epoch 3/5 [Validation]:   0%|          | 0/57 [00:00<?, ?it/s]
# Epoch 3/5 - Train Loss: 1.2824, Val Loss: 1.1763, Val Acc: 0.5906
# Epoch 4/5 [Training]:   0%|          | 0/263 [00:00<?, ?it/s]
# Epoch 4/5 [Validation]:   0%|          | 0/57 [00:00<?, ?it/s]
# Epoch 4/5 - Train Loss: 1.1466, Val Loss: 0.9741, Val Acc: 0.6729
# Epoch 5/5 [Training]:   0%|          | 0/263 [00:00<?, ?it/s]
# Epoch 5/5 [Validation]:   0%|          | 0/57 [00:00<?, ?it/s]
# Epoch 5/5 - Train Loss: 1.0415, Val Loss: 0.9352, Val Acc: 0.6942

# %%
helper_utils.plot_training_logs(history_resnet1, history_resnet2, model_name1="Simple ResNet1", model_name2="Simple ResNet2")
# Out:
# ---------- Final Validation Accuracies ---------
# Simple ResNet1      |  Accuracy: 66.95%
# Simple ResNet2   |  Accuracy: 69.42%
# ------------------------------------------------
